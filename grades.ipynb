# %%
import pandas as pd

# Load data from a text file
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv
df_students = pd.read_csv('grades.csv.3',delimiter=',',header='infer')

# Remove any rows with missing data
df_students = df_students.dropna(axis=0, how="any")

# Calclulate who passed, assuming '60' is the grade needed to pass
passes  = pd.Series(df_students['Grade'] >= 60)

# Save who passed to the Pandas dataframe
df_students = pd.concat([df_students, passes.rename("Pass")], axis=1)

# Print the result out into this notebook
# df_students

# %%
df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(10,4))
ax[0].bar(x=df_students.Name, height=df_students.Grade)
ax[0].set_title("Student Grades")
# plt.xlabel("Name")
# plt.ylabel("Grade")
# ax[0].set_xtickslabels(df_students.Name, rotation=60)
# ax[0].show()

passes_count = df_students.Pass.value_counts()
ax[1].pie(passes_count, labels=passes_count)
ax[1].set_title("Passing Grades")
fig.show()
# Out:
# /tmp/ipykernel_3704475/2862520637.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df_students.plot.bar(x="Name", y='Grade', figsize=(10,4), color="crimson")
# Out:
# <AxesSubplot: xlabel='Name'>

# %%
min_val = df_students.Grade.min()
max_val = df_students.Grade.max()
mean_val = df_students.Grade.mean()
med_val = df_students.Grade.median()
mod_val = df_students.Grade.mode()[0]
print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                        mean_val,
                                                                                        med_val,
                                                                                        mod_val,
                                                                                        max_val))
grades = df_students.Grade
fig = plt.figure(figsize=(10,4))
plt.hist(grades)
plt.axvline(x=min_val, color="crimson")

plt.axvline(x=max_val, color="crimson")
plt.axvline(x=mean_val, color="cyan")
plt.axvline(x=med_val, color="gray")
plt.axvline(x=mod_val, color="white")

plt.title("Data Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
fig.show()
# Out:
# Minimum:3.00
# Mean:49.18
# Median:49.50
# Mode:50.00
# Maximum:97.00
# /tmp/ipykernel_3704475/661144670.py:24: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
grades = df_students.Grade

fig = plt.figure(figsize=(10,4))
plt.boxplot(grades, vert=False)
plt.title("Data Distribution")
fig.show()
# Out:
# /tmp/ipykernel_3704475/1839091100.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def show_density(data):
    fig = plt.figure(figsize=(10,4))
    data.plot.density()
    plt.title('Data Density')
    plt.show()
    
show_density(df_students.Grade)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/gnull/dev/projects/python/2018-and-2020/explore-data/grades.ipynb Cell 7 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/home/gnull/dev/projects/python/2018-and-2020/explore-data/grades.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     plt.title('Data Density')
#       <a href='vscode-notebook-cell:/home/gnull/dev/projects/python/2018-and-2020/explore-data/grades.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     plt.show()
# ----> <a href='vscode-notebook-cell:/home/gnull/dev/projects/python/2018-and-2020/explore-data/grades.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> show_density(df_students.Grade)
#
# /home/gnull/dev/projects/python/2018-and-2020/explore-data/grades.ipynb Cell 7 in show_density(data)
# ...
